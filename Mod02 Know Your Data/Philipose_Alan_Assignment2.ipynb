# %% [markdown]
# # Assignment 2
#
# In this exercise, you are provided with data regarding income, education, and other attributes collected from various people for the purposes of a study. As a first step, a data analyst must measure the central tendency of the numerical attributes.
#
# ---
# ### Instructions
# 1. Import the following modules:
#     * `pandas` is used for creating our dataframe
#     * `numpy` is used for calculating certain values
#     * `matplotlib.pyplot` is used for plotting graphs
# 2. Create a dataframe of the data contained in **Income Data.csv** using `pandas`. You may use the code from Assignment 1 (assuming it works :P).

# %%
# Code here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 3. For *Income*, *Education*, and *Prestige* calculate and display the following data:
#     - Minimum Value
#     - 1st Quartile
#     - Median
#     - Mean
#     - 3rd Quartile
#     - Maximum Value

# %%
# Code here


df = pd.read_csv("./Income Data.csv")

# for col in ["income", "education", "prestige"]: 
#     s = df[col]
#     print(f"Min: {s.min()}")
#     print(f"1st Quartile: {s.quantile(0.25)}")
#     print(f"Median / 2nd Quartile: {s.median()}")
#     print(f"Mean: {s.mean()}")
#     print(f"3rd Quartile: {s.quantile(0.75)}")
#     print(f"Max: {s.max()}")

print(df.describe()) # this does all of the code above in one line
# Out:
#           income   education   prestige
# count  45.000000   45.000000  45.000000
# mean   41.866667   52.555556  47.688889
# std    24.435072   29.760831  31.510332
# min     7.000000    7.000000   3.000000
# 25%    21.000000   26.000000  16.000000
# 50%    42.000000   45.000000  41.000000
# 75%    64.000000   84.000000  81.000000
# max    81.000000  100.000000  97.000000

# %% [markdown]
# 4. Plot a *histogram* for **prestige**
# 5. Plot a *histogram* for **education**

# %%
# Code here

# Histogram for prestige

plt.hist(df["prestige"])
plt.title("prestige")
plt.show()


# histogram for education

plt.hist(df["education"])
plt.title("education")
plt.show()

# %% [markdown]
# 6. Plot a *scatter plot* for **income** and **education**
# 7. Plot a *scatter plot* for **education** and **prestige**

# %%
# Code here
# code for scatter plot comparing income and education
plt.scatter(x = df['income'], y= df['education'])
plt.xlabel("Income")
plt.ylabel("Education")
# Out:
# Text(0, 0.5, 'Education')

# %%
# code for scatter plot for comparing education and prestige
plt.scatter(x = df['education'], y= df['prestige'])
plt.xlabel("Education")
plt.ylabel("Prestige")
# Out:
# Text(0, 0.5, 'Prestige')

# %% [markdown]
# 8. Calculate and display the *variance* and *standard deviation* for **income**

# %%
# Code here

# standard dev. for income
np.std(df["income"])
# Out:
# np.float64(24.162045535186884)

# %%
# variance for income

np.var(df["income"])
# Out:
# np.float64(583.8044444444444)

# %% [markdown]
# In the  `Markdown` cell below, answer the following questions:
#
# 9. Explain what variance measures
# 10. What does a high variance value suggest?
# 11. As a data analyst, if you calculate the income variance and it is 0, what does that mean? Is it good or bad?

# %% [markdown]
# 9. Variance measures how spread out the data is from the mean. It shows how far off data values are form the mean.
# 10. A high variance value suggest that means that the data is widely spread out from the mean.
# 11. If I calculate the income variance, and it is 0, that means that the data values are exactly the same to the mean. There are no difference between the incomes. It can be good or bad depending on the situation that you are working with. In this situation, it means that all the income values are the same meaning everyone is getting paid the same. If that is what you want to achieve, then it can be a good thing, but can be bad in other situations.

# %% [markdown]
# 12. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment2.ipynb**
#     - Replace '**Last**' and '**First**' with your name
